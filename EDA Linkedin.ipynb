# %%
import pandas as pd
import re

# %%
df = pd.read_csv("linkedin-jobs-usa.csv")

# %%
df
# Out:
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2840             Junior Data Analyst        Iris Software Inc.
# 2841              Data Analyst (SQL)             Marwood Group
# 2842                    Data Analyst        SmartSense by Digi
# 2843                    Data Analyst            Synergy Search
# 2844                    Data Analyst            Insight Global
#
#                                             description onsite_remote  \
# 0     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2845 non-null   object
#  1   company        2845 non-null   object
#  2   description    2845 non-null   object
#  3   onsite_remote  2845 non-null   object
#  4   salary         929 non-null    object
#  5   location       2845 non-null   object
#  6   criteria       2845 non-null   object
#  7   posted_date    2845 non-null   object
#  8   link           2845 non-null   object
# dtypes: object(9)
# memory usage: 200.2+ KB

# %%
df.nunique()
# Out:
# title              37
# company           171
# description       199
# onsite_remote       3
# salary             45
# location          112
# criteria          138
# posted_date        33
# link             2845
# dtype: int64

# %%
df.isnull().sum()
# Out:
# title               0
# company             0
# description         0
# onsite_remote       0
# salary           1916
# location            0
# criteria            0
# posted_date         0
# link                0
# dtype: int64

# %%
df["salary"] = df["salary"].fillna("Nan")

# %%
start = []
end = []
for i in df["salary"]:
    if i == "Nan":
        start.append("Nan")
        end.append("Nan")
    else:
        a = i.split(".")
        res = re.sub(r'[^\w\s]', '', str(a))
        v = re.findall(r'\d+', str(res))
        start.append(v[0])
        end.append(v[2])

# %%
df["Start_salary"] = start
df["End Salary"] = end

# %%
df.drop(["salary"],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                title company  \
# count           2845    2845
# unique            37     171
# top     Data Analyst  PayPal
# freq            2110     499
#
#                                               description onsite_remote  \
# count                                                2845          2845
# unique                                                199             3
# top     At PayPal (NASDAQ: PYPL), we believe that ever...        remote
# freq                                                  309           970
#
#              location                                           criteria  \
# count            2845                                               2845
# unique            112                                                138
# top     United States  [{'Seniority level': 'Not Applicable'}, {'Empl...
# freq              632                                                489
#
#        posted_date                                               link  \
# ...

# %%
df["criteria"][0]
# Out:
# "[{'Seniority level': 'Not Applicable'}, {'Employment type': 'Full-time'}, {'Job function': 'Information Technology'}, {'Industries': 'Software Development, Technology, Information and Internet, and Financial Services'}]"

# %%
cr = df["criteria"][0]
vv = cr.split("}")[3]
print(vv)
vv = vv.split(":")
two = re.sub(r'[^\w\s]', '', str(vv[1]))
print(two.strip())
# Out:
# , {'Industries': 'Software Development, Technology, Information and Internet, and Financial Services'
# Software Development Technology Information and Internet and Financial Services

# %%
Seniority_level = []
Employment_type = []
Job_function = []
Industry = []
# ss = -1
for i in df["criteria"]:
    try:
        val_0 = i.split("}")[0]
        val_0 = val_0.split(":")
    #     ss = ss+1
    #     print(ss)
        val_0 = re.sub(r'[^\w\s]', '', str(val_0[1]))
        Seniority_level.append(val_0)
    except IndexError:
        Seniority_level.append("null")
        
    try:    
        val_1 = i.split("}")[1]
        val_1 = val_1.split(":")
        val_1 = re.sub(r'[^\w\s]', '', str(val_1[1]))
        Employment_type.append(val_1)
    except IndexError:
        Employment_type.append("null")
        
    try:    
        val_2 = i.split("}")[2]
        val_2 = val_2.split(":")
        val_2 = re.sub(r'[^\w\s]', '', str(val_2[1]))
        Job_function.append(val_2)
    except IndexError:
        Job_function.append("null")    
        
    try:
        val_3 = i.split("}")[3]
        val_3 = val_3.split(":")
        val_3 = re.sub(r'[^\w\s]', '', str(val_3[1]))
        Industry.append(val_3)
    except IndexError:
        Industry.append("null")

# %%
df["Seniority_level"] = Seniority_level
df["Employment_type"] = Employment_type
df["Job_function"] = Job_function
df["Industry"] = Industry

# %%
df.head()
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
#
#                                          description onsite_remote  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 3  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# 4  The Federal Savings Bank, a national bank and ...        onsite
#
#                      location  \
# 0  Buffalo-Niagara Falls Area
# 1                San Jose, CA
# 2        Texas, United States
# 3     Illinois, United States
# 4                 Chicago, IL
#
# ...

# %%
cities = []
for i in df["location"]:
    cities.append(i.split(",")[0])

# %%
s = set(cities)
s
# Out:
# {'Alpharetta',
#  'Ann Arbor',
#  'Annapolis',
#  'Arizona',
#  'Atlanta',
#  'Atlanta Metropolitan Area',
#  'Austin',
#  'Bellevue',
#  'Boston',
#  'Bridgewater',
#  'Buffalo-Niagara Falls Area',
#  'Burbank',
#  'Camden',
#  'Carlsbad',
#  'Cedar Rapids',
#  'Charlotte',
#  'Charlotte Metro',
#  'Chicago',
#  'Cincinnati',
#  'Cincinnati Metropolitan Area',
#  'Cleveland',
#  'Columbia',
#  'Columbus',
#  'Conshohocken',
#  'Crystal City',
#  'Dallas',
#  'Dallas-Fort Worth Metroplex',
#  'Delray Beach',
#  'Denver Metropolitan Area',
#  'Des Moines',
#  'Detroit',
#  'District of Columbia',
#  'Dublin',
#  'Eden Prairie',
#  'Fort Lauderdale',
#  'Franklin',
#  'Georgia',
#  'Greater Sacramento',
#  'Greater Scranton Area',
#  'Greater Tampa Bay Area',
#  'Greensboro--Winston-Salem--High Point Area',
#  'Hartford',
#  'Hoffman Estates',
#  'Home',
#  'Houston',
#  'Huntersville',
#  'Illinois',
#  'Indiana',
#  'Irvine',
#  'Irving',
#  'Kansas City Metropolitan Area',
# ...

# %%
df.to_csv("Cleaned_Linkedin_data.csv")
